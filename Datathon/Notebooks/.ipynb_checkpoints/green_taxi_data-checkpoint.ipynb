# %%
import pandas as pd
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon, MultiPoint

# %%
geographic = pd.read_csv('/home/shade/DS4A/Data/Dataset/Dataset/geographic.csv')
ny_shp = gpd.read_file("/home/shade/DS4A/Data/Dataset/Shapes/nta_map.shp")
ny_shp_dissolve = gpd.read_file("/home/shade/DS4A/Data/Dataset/Shapes/Dissolve.shp")

# %%
df = pd.DataFrame(geographic.columns.sort_values())

# %%
df[0].sort_values().equals(ny_shp['ntacode'].sort_values().reset_index(drop=True))
# Out:
# True

# %%
green_taxi = pd.read_csv('/home/shade/DS4A/Data/Dataset/Dataset/green_trips.csv')

# %%
green_taxi.head()
# Out:
#        pickup_datetime     dropoff_datetime  pickup_longitude  \
# 0  2015-02-01 01:26:45  2015-02-01 01:49:58        -73.953545
# 1  2015-01-02 20:06:28  2015-01-02 20:14:04        -73.946709
# 2  2014-09-27 17:55:38  2014-09-27 18:19:56        -73.957626
# 3  2014-04-27 02:27:04  2014-04-27 02:39:02        -73.949501
# 4  2014-05-26 18:32:19  2014-05-26 18:44:13        -73.944092
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0        40.811172         -73.984764         40.728386                1
# 1        40.714321         -73.961571         40.711475                1
# 2        40.718094         -73.947304         40.777813                5
# 3        40.713997         -73.987785         40.718582                2
# 4        40.672195         -73.977325         40.664013                1
#
#    trip_distance  total_amount
# 0           8.11          27.8
# 1           1.29           9.8
# 2           6.12          26.3
# 3           3.68          17.3
# 4           2.40          11.5

# %%
green_taxi_Points =[Point(x, y) for x, y in zip(green_taxi['pickup_longitude'], green_taxi['pickup_latitude'])]
geo_green_taxi = gpd.GeoDataFrame(green_taxi, geometry=green_taxi_Points)

# %%
fig, ax = plt.subplots(figsize = (20,16))
ny_shp.plot(figsize=(20,16), alpha=0.1, edgecolor='k', ax=ax)
geo_green_taxi.plot(figsize=(20,16), edgecolor='green', color='green', ax=ax)

# %%
bounds = ny_shp.loc[0,'geometry'].bounds
bounds = ny_shp.geometry.total_bounds
df_filtered = geo_green_taxi.dropna()

print(bounds)

df_filtered = df_filtered[df_filtered['dropoff_longitude'] > bounds[0]]
df_filtered = df_filtered[df_filtered['dropoff_longitude'] < bounds[2]]
df_filtered = df_filtered[df_filtered['dropoff_latitude'] > bounds[1]]
df_filtered = df_filtered[df_filtered['dropoff_latitude'] < bounds[3]]

print(df_filtered['dropoff_longitude'].max())
print(df_filtered['dropoff_longitude'].min())
print(df_filtered['dropoff_latitude'].max())
print(df_filtered['dropoff_latitude'].min())
# Out:
# [-74.25559136  40.4961154  -73.70000906  40.91553278]
# -73.7000274658
# -74.255531311
# 40.9155158997
# 40.5071105957
# (3578675, 10)
# (3578675, 10)

# %%
df_filtered['dropoff_longitude'].sort_values(ascending=False)
# Out:
# 1570109   -73.700027
# 1726615   -73.700027
# 1250435   -73.700043
# 2786098   -73.700111
# 3024240   -73.700119
#              ...
# 106845    -74.251221
# 1229732   -74.253227
# 1156305   -74.253540
# 3054974   -74.255287
# 1105372   -74.255531
# Name: dropoff_longitude, Length: 3578675, dtype: float64

# %%
df_filtered.shape
# Out:
# (3578675, 10)

# %%
fig, ax = plt.subplots(figsize = (20,16))
ny_shp.plot(figsize=(20,16), alpha=0.1, edgecolor='k', ax=ax)
df_filtered.plot(figsize=(20,16), edgecolor='green', color='green', ax=ax)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-8bd5a4a2e2e2> in <module>
#       1 fig, ax = plt.subplots(figsize = (20,16))
#       2 ny_shp.plot(figsize=(20,16), alpha=0.1, edgecolor='k', ax=ax)
# ----> 3 df_filtered.plot(figsize=(20,16), edgecolor='green', color='green', ax=ax)
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     532         from there.
#     533         """
# --> 534         return plot_dataframe(self, *args, **kwargs)
#     535
#     536     plot.__doc__ = plot_dataframe.__doc__
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, **style_kwds)
#     412         return plot_series(df.geometry, cmap=cmap, color=color, ax=ax,
#     413                            figsize=figsize, markersize=markersize,
# --> 414                            **style_kwds)
#     415
#     416     # To accept pd.Series and np.arrays as column
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/plotting.py in plot_series(s, cmap, color, ax, figsize, **style_kwds)
#     306         values_ = values[point_idx] if cmap else None
#     307         plot_point_collection(ax, points, values_, color=color, cmap=cmap,
# --> 308                               **style_kwds)
#     309
#     310     plt.draw()
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/plotting.py in plot_point_collection(ax, geoms, values, color, cmap, vmin, vmax, marker, markersize, **kwargs)
#     196         values = None
#     197     x = [p.x for p in geoms]
# --> 198     y = [p.y for p in geoms]
#     199
#     200     # matplotlib 1.4 does not support c=None, and < 2.0 does not support s=None
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/plotting.py in <listcomp>(.0)
#     196         values = None
#     197     x = [p.x for p in geoms]
# --> 198     y = [p.y for p in geoms]
#     199
#     200     # matplotlib 1.4 does not support c=None, and < 2.0 does not support s=None
#
# ~/anaconda3/lib/python3.7/site-packages/shapely/geometry/point.py in y(self)
#      59     def y(self):
#      60         """Return y coordinate."""
# ---> 61         return self.coords[0][1]
#      62
#      63     @property
#
# KeyboardInterrupt:

# %%
geo_green_taxi_intersect = geo_green_taxi.loc[res_intersection]
geo_green_taxi_intersect
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-522a026dab28> in <module>
# ----> 1 geo_green_taxi_intersect = geo_green_taxi.loc[res_intersection]
#       2 geo_green_taxi_intersect
#
# NameError: name 'res_intersection' is not defined

# %%
ny_shp.plot(figsize=(20,16), alpha=0.1, edgecolor='k', ax=ax)
geo_green_taxi[geo_green_taxi==res_intersection].plot(figsize=(20,16), edgecolor='green', color='green', ax=ax)
